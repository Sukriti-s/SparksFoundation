# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\sukriti\anaconda3\lib\site-packages (3.6.1)
# Requirement already satisfied: joblib in c:\users\sukriti\anaconda3\lib\site-packages (from nltk) (1.0.1)
# Requirement already satisfied: tqdm in c:\users\sukriti\anaconda3\lib\site-packages (from nltk) (4.59.0)
# Requirement already satisfied: click in c:\users\sukriti\anaconda3\lib\site-packages (from nltk) (7.1.2)
# Requirement already satisfied: regex in c:\users\sukriti\anaconda3\lib\site-packages (from nltk) (2021.4.4)

# %%
#Loading NLTK
import nltk

# %%
from nltk.tokenize import sent_tokenize

# %%
from nltk.tokenize import word_tokenize

# %%
## List of stop words

from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
print(stop_words)
# Out:
# {'of', 'how', "should've", 'that', 'each', 'him', 'few', 'this', 'hers', "you're", 'below', "hasn't", 'y', 'itself', 'until', 'where', 'isn', 'll', "couldn't", 'as', 'won', 'do', 'above', 'with', "aren't", "haven't", 'me', 'after', "doesn't", 'his', 'what', "that'll", 'has', 'those', 'been', 'doesn', 'its', 'now', 'be', 'there', 'ourselves', 'aren', "isn't", 'more', 'own', 'if', 'such', 'and', 'than', 'you', 'so', 'didn', 'myself', 'was', 'having', 'or', 'again', 'themselves', 'when', 'is', 'm', 'any', 'nor', 'too', 'down', 'mightn', 'needn', "you'd", "didn't", 'weren', 'i', 'o', "wouldn't", 'did', 'but', 'just', 'the', 't', 'not', "needn't", 'my', 'will', "shan't", "don't", 'am', 'yours', 'during', 'our', 'ma', "weren't", 'for', 'up', "hadn't", 'ours', "mustn't", 'out', 'being', 'through', 'same', 'against', 're', 'wouldn', 'some', 'whom', 'once', 'into', 'further', 'shan', 'mustn', "you'll", "won't", 'she', 'these', 'an', 'then', 'off', 'we', 'can', 'had', 'should', 'at', 'they', 'between', 'himself', "it's", 'other', 'shouldn', 'haven', 'under', "mightn't", 'their', 'why', 'he', 'about', 'from', 'herself', 'most', "shouldn't", 'yourselves', 'very', 'hasn', 'which', 'were', 'ain', 'hadn', 'doing', 'are', 'here', 'only', 'theirs', 'it', 'all', 'wasn', "you've", 'her', 'in', 'them', "she's", 'to', 'no', 'd', "wasn't", 'over', 'your', 's', 've', 'both', 'don', 'on', 'because', 'before', 'does', 'who', 'have', 'a', 'yourself', 'while', 'couldn', 'by'}

# %%
## Removing Punctuation

filename = 'C:/Users/sukriti/Desktop/taleoftwocities.txt'
with open(filename, encoding="utf8") as f:
    text = f.read()
f.close()

# split into words
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)

# convert to lower case
tokens = [w.lower() for w in tokens]

# remove punctuation from each word
import string
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in tokens]

# remove remaining tokens that are not alphabetic
words = [word for word in stripped if word.isalpha()]

# filter out stop words
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]
print(words[:100])
# Out:
# ['project', 'gutenberg', 'ebook', 'tale', 'two', 'cities', 'charles', 'dickens', 'ebook', 'use', 'anyone', 'anywhere', 'united', 'states', 'parts', 'world', 'cost', 'almost', 'restrictions', 'whatsoever', 'may', 'copy', 'give', 'away', 'reuse', 'terms', 'project', 'gutenberg', 'license', 'included', 'ebook', 'online', 'wwwgutenbergorg', 'located', 'united', 'states', 'check', 'laws', 'country', 'located', 'using', 'ebook', 'title', 'tale', 'two', 'cities', 'story', 'french', 'revolution', 'author', 'charles', 'dickens', 'release', 'date', 'january', 'ebook', 'recently', 'updated', 'december', 'language', 'english', 'character', 'set', 'encoding', 'produced', 'judith', 'boss', 'david', 'widger', 'start', 'project', 'gutenberg', 'ebook', 'tale', 'two', 'cities', 'tale', 'two', 'cities', 'story', 'french', 'revolution', 'charles', 'dickens', 'contents', 'book', 'first', 'recalled', 'life', 'chapter', 'period', 'chapter', 'ii', 'mail', 'chapter', 'iii', 'night', 'shadows', 'chapter', 'iv']

# %%
len(words)
# Out:
# 65234

# %%
from collections import Counter
fdist = Counter(words)

ans = {k: v for k, v in reversed(sorted(fdist.items(), key=lambda item: item[1]))}

# %%
fdist.most_common()[:10]
# Out:
# [('said', 661),
#  ('mr', 622),
#  ('one', 442),
#  ('lorry', 369),
#  ('would', 343),
#  ('defarge', 302),
#  ('man', 295),
#  ('upon', 291),
#  ('could', 283),
#  ('little', 267)]

# %%
fdist.most_common()[-10:]
# Out:
# [('michael', 1),
#  ('hart', 1),
#  ('library', 1),
#  ('volunteer', 1),
#  ('edition', 1),
#  ('pg', 1),
#  ('facility', 1),
#  ('includes', 1),
#  ('subscribe', 1),
#  ('newsletter', 1)]

# %%
fdist.items()
# Out:
# dict_items([('project', 88), ('gutenberg', 31), ('ebook', 13), ('tale', 6), ('two', 214), ('cities', 6), ('charles', 102), ('dickens', 3), ('use', 30), ('anyone', 5), ('anywhere', 6), ('united', 21), ('states', 21), ('parts', 5), ('world', 46), ('cost', 6), ('almost', 48), ('restrictions', 2), ('whatsoever', 3), ('may', 142), ('copy', 12), ('give', 50), ('away', 137), ('reuse', 2), ('terms', 27), ('license', 18), ('included', 5), ('online', 4), ('wwwgutenbergorg', 5), ('located', 7), ('check', 10), ('laws', 13), ('country', 40), ('using', 10), ('title', 3), ('story', 23), ('french', 46), ('revolution', 9), ('author', 1), ('release', 6), ('date', 9), ('january', 1), ('recently', 3), ('updated', 2), ('december', 4), ('language', 7), ('english', 47), ('character', 20), ('set', 58), ('encoding', 1), ('produced', 11), ('judith', 1), ('boss', 1), ('david', 1), ('widger', 1), ('start', 13), ('contents', 4), ('book', 12), ('first', 118), ('recalled', 19), ('life', 158), ('chapter', 90), ('period', 7), ('ii', 7), ('mail', 27), ('iii', 6), ('night', 187), ('shadows', 22), ('iv', 6), ('preparation', 10), ('v', 6), ('wineshop', 52), ('vi', 6), ('shoemaker', 19), ('second', 34), ('golden', 29), ('thread', 6), ('five', 38), ('years', 89), ('later', 7), ('sight', 42), ('disappointment', 4), ('congratulatory', 2), ('jackal', 16), ('hundreds', 15), ('people', 143), ('vii', 4), ('monseigneur', 109), ('town', 14), ('viii', 4), ('ix', 4), ('gorgon', 4), ('head', 174), ('x', 4), ('promises', 3), ('xi', 4), ('companion', 10), ('picture', 9), ('xii', 4), ('fellow', 35), ('delicacy', 12), ('xiii', 4), ('xiv', 4), ('honest', 21), ('tradesman', 17), ('xv', 4), ('knitting', 44), ('xvi', 2), ('still', 100), ('xvii', 2), ('one', 442), ('xviii', 2), ('nine', 16), ('days', 54), ('xix', 2), ('opinion', 18), ('xx', 2), ('plea', 3), ('xxi', 2), ('echoing', 5), ('footsteps', 21), ('xxii', 2), ('sea', 34), ('rises', 5), ('xxiii', 2), ('fire', 55), ('xxiv', 2), ('drawn', 20), ('loadstone', 5), ('rock', 7), ('third', 25), ('track', 4), ('storm', 15), ('secret', 42), ('grindstone', 11), ('shadow', 33), ('calm', 11), ('woodsawyer', 14), ('triumph', 7), ('knock', 3), ('door', 121), ('hand', 249), ('cards', 12), ('game', 5), ('made', 185), ('substance', 4), ('dusk', 4), ('darkness', 29), ('fiftytwo', 8), ('done', 98), ('die', 25), ('ever', 118), ('best', 40), ('times', 51), ('worst', 18), ('age', 20), ('wisdom', 2), ('foolishness', 1), ('epoch', 2), ('belief', 6), ('incredulity', 1), ('season', 7), ('light', 89), ('spring', 5), ('hope', 85), ('winter', 11), ('despair', 6), ('everything', 27), ('us', 116), ('nothing', 151), ('going', 88), ('direct', 9), ('heaven', 37), ('way', 187), ('short', 40), ('far', 81), ('like', 209), ('present', 41), ('noisiest', 1), ('authorities', 3), ('insisted', 2), ('received', 28), ('good', 210), ('evil', 9), ('superlative', 1), ('degree', 11), ('comparison', 4), ('king', 31), ('large', 37), ('jaw', 2), ('queen', 11), ('plain', 17), ('face', 187), ('throne', 3), ('england', 40), ('fair', 20), ('france', 59), ('countries', 3), ('clearer', 1), ('crystal', 1), ('lords', 6), ('state', 57), ('preserves', 1), ('loaves', 2), ('fishes', 1), ('things', 69), ('general', 32), ('settled', 5), ('year', 36), ('lord', 26), ('thousand', 26), ('seven', 24), ('hundred', 42), ('seventyfive', 5), ('spiritual', 2), ('revelations', 1), ('conceded', 1), ('favoured', 6), ('mrs', 18), ('southcott', 1), ('attained', 1), ('fiveandtwentieth', 1), ('blessed', 8), ('birthday', 2), ('prophetic', 3), ('private', 11), ('guards', 3), ('heralded', 2), ('sublime', 3), ('appearance', 29), ('announcing', 1), ('arrangements', 9), ('swallowing', 3), ('london', 28), ('westminster', 2), ('even', 129), ('cocklane', 2), ('ghost', 16), ('laid', 52), ('round', 65), ('dozen', 7), ('rapping', 1), ('messages', 3), ('spirits', 10), ('last', 135), ('past', 26), ('supernaturally', 1), ('deficient', 1), ('originality', 1), ('rapped', 2), ('mere', 23), ('earthly', 5), ('order', 17), ('events ...

# %%
## Calculating highest and least frequency words
#Frequecy distribution of words
from nltk.probability import FreqDist
fdist = FreqDist(words)
print(fdist)

fdist
# Out:
# <FreqDist with 10140 samples and 65234 outcomes>
# FreqDist({'said': 661, 'mr': 622, 'one': 442, 'lorry': 369, 'would': 343, 'defarge': 302, 'man': 295, 'upon': 291, 'could': 283, 'little': 267, ...})

# %%
fdist.most_common(10)
# Out:
# [('said', 661),
#  ('mr', 622),
#  ('one', 442),
#  ('lorry', 369),
#  ('would', 343),
#  ('defarge', 302),
#  ('man', 295),
#  ('upon', 291),
#  ('could', 283),
#  ('little', 267)]
